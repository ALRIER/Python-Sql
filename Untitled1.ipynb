# %%
import mysql.connector
from mysql.connector import Error

# %%
def crear_conexion(nombre_host, usuario, contrasena, basedatos):
    conexion = None
    try:
        conexion = mysql.connector.connect(
                host = nombre_host,
                user = usuario,
                passwd = contrasena,
                database = basedatos
                )        
    except Error as e:
        print("Error al establecer conexión: ",e)
    
    return conexion

def visualizar_municipio(connection):
    
    #numid = input('Digite id: ')
    nm= input('Digite nombre municipio: ')
    if(connection != None):
        cursor = connection.cursor(dictionary=True)
        result = None
        try:
            cursor.execute("SELECT * FROM produccion_view WHERE nombre_mun = '" + nm + "'")  #aqui hay lenguaje sql, tabla de datos vendedor
            result = cursor.fetchall()        
        except Error as e:
            print("Se ha presentado error: ",e)
        if(len(result) > 0):
            for row in result:
                print(row)       
        else:
            print("No se encontraron resultados")
    else:
        print('No es posible ejecutar la consulta')

def tres(connection):
    
    #numid = input('Digite id: ')
    cc= int(input('Digite la CC delvendedor que desea eliminar del regictro: '))
    if(connection != None):
        cursor = connection.cursor(dictionary=True)
        result = None
        try:
            cursor.execute("DELET * FROM vendedor WHERE identificacion = '" + cc + "'")  #aqui hay lenguaje sql, tabla de datos vendedor
            result = cursor.fetchall()        
        except Error as e:
            print("Se ha presentado error: ",e)
        if(len(result) > 0):
            for row in result:
                print(row)       
        else:
            print("No se encontraron resultados")
    else:
        print('No es posible ejecutar la consulta')
        
        
def cuatro(connection):
    #numid = input('Digite id: ')
    cc= int(input('Digite la CC del nuevo vendedor: '))
    if(connection != None):
        cursor = connection.cursor(dictionary=True)
        result = None
        try:
            cursor.execute("INSERT INTO vendedor (identificacion) = '" + cc + "'")  
            result = cursor.fetchall()        
        except Error as e:
            print("Se ha presentado error: ",e)
        if(len(result) > 0):
            for row in result:
                print(row)       
        else:
            print("No se encontraron resultados")
    else:
        print('No es posible ejecutar la consulta')        

print(""" 
      
 ¡Bienvenido!
 _  __                         _   _                                           
 | |/ /                        | | | |                                          
 | ' / ___  _ __  _ __ __ _  __| | | |     ___  _ __ ___ _ __  ____             
 |  < / _ \| '_ \| '__/ _` |/ _` | | |    / _ \| '__/ _ \ '_ \|_  /             
 | . \ (_) | | | | | | (_| | (_| | | |___| (_) | | |  __/ | | |/ /              
 |_|\_\___/|_| |_|_|  \__,_|\__,_| |______\___/|_|  \___|_| |_/___|             
 """)

con = crear_conexion('34.122.51.150','alvaroriverae','alvaroriverae','alvaroriverae')

continuar = True

while continuar:
    
    print(""" 
              **************
              Menu principal
              **************
          """)
    print("Ingrese una opción:")
    print("Visualizar datos producción (1)")
    print("Visualizar datos de producción de un municipio (2)")
    print("Actualizar el valor de producción de un registro dado el ID del registro (3)")   
    print("Crear tabla reporte con los datos de la vista produccion_view (R)")    
    print("Salir (S o s)")
    
    opcion = input("Ingresa una opción: ")
    
    if opcion == "1":
        consulta_registros(con,'SELECT * FROM produccion')
    elif opcion == "2":
        #print('Visualizar datos de producción de un municipio')
        visualizar_municipio(con)
    elif opcion == "3":
        #print('Actualizar el valor de producción de un registro dado el ID del registro')
        #crear función que solicite la cedula del vendedor y lo eliminde de la tabla vendedores
        tres(con)
    elif opcion == "R" or opcion == "r":
        print('Crear tabla reporte con nombre reporteprod con los datos de la vista produccion_view')
        #crear función que solicite la cedula y el nuevo nombre del vendedor y lo modifique            
    elif opcion == "S" or opcion == "s":
        continuar = False
    else:
        print("""
              
        Opción incorrecta, intente nuevamente
              
        """)
    
print("""
      ¡Hasta pronto!
 _  __                         _   _                                           
 | |/ /                        | | | |                                          
 | ' / ___  _ __  _ __ __ _  __| | | |     ___  _ __ ___ _ __  ____             
 |  < / _ \| '_ \| '__/ _` |/ _` | | |    / _ \| '__/ _ \ '_ \|_  /             
 | . \ (_) | | | | | | (_| | (_| | | |___| (_) | | |  __/ | | |/ /              
 |_|\_\___/|_| |_|_|  \__,_|\__,_| |______\___/|_|  \___|_| |_/___|             
 """)

        
con.close()        

# Crear informe en google datastudio con los datos de la tabla reporte que visualice:
# Producción por municipio
# Producción por tipo de cultivo
# El rendimiento por tipo de cultivo
# Tabla con el nombre del municipio, nombre del cultivo, área sembrada, rendimiento, producción
# Out:
#
#
#  ¡Bienvenido!
#  _  __                         _   _
#  | |/ /                        | | | |
#  | ' / ___  _ __  _ __ __ _  __| | | |     ___  _ __ ___ _ __  ____
#  |  < / _ \| '_ \| '__/ _` |/ _` | | |    / _ \| '__/ _ \ '_ \|_  /
#  | . \ (_) | | | | | | (_| | (_| | | |___| (_) | | |  __/ | | |/ /
#  |_|\_\___/|_| |_|_|  \__,_|\__,_| |______\___/|_|  \___|_| |_/___|
#
#
#               **************
#               Menu principal
#               **************
#
# Ingrese una opción:
# Visualizar datos producción (1)
# Visualizar datos de producción de un municipio (2)
# Actualizar el valor de producción de un registro dado el ID del registro (3)
# Crear tabla reporte con los datos de la vista produccion_view (R)
# Salir (S o s)
# Ingresa una opción:  3
# Digite la CC delvendedor que desea eliminar del regictro:  112131313
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-0478ad5e147e> in <module>
#      92         #print('Actualizar el valor de producción de un registro dado el ID del registro')
#      93         #crear función que solicite la cedula del vendedor y lo eliminde de la tabla vendedores
# ---> 94         tres(con)
#      95     elif opcion == "R" or opcion == "r":
#      96         print('Crear tabla reporte con nombre reporteprod con los datos de la vista produccion_view')
#
# <ipython-input-8-0478ad5e147e> in tres(connection)
#      41         result = None
#      42         try:
# ---> 43             cursor.execute("DELET * FROM vendedor WHERE identificacion = '" + cc + "'")  #aqui hay lenguaje sql, tabla de datos vendedor
#      44             result = cursor.fetchall()
#      45         except Error as e:
#
# TypeError: can only concatenate str (not "int") to str
